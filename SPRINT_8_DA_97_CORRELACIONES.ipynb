# %% [markdown]
# <a href="https://colab.research.google.com/github/hector1994/git_testing_sprint7_cohorte_97/blob/main/SPRINT_8_DA_97_CORRELACIONES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# El día de hoy, he trabajado con mis estudiantes relativo al tema de Github.

# %% [markdown]
# ## 📤 __IMPORTS PRINCIPALES Y CONFIGURACIONES GLOBALES__⚙️
# ---

# %%
#IMPORTS PRINCIPALES:
import pandas  as pd               #LECTURA, MANEJO Y TRANSFORMACIÓN DE DATAFRAMES.
import numpy   as np               #FUNCIONES MATEMÁTICAS RELEVANTES.
import matplotlib.pyplot as plt    #GRÁFICOS.
import seaborn as sns              #GRÁFICOS PRETTY.

#CONFIGURACIONES GLOBALES:
import warnings                                                #MANEJO DE WARNINGS - ADVERTENCIAS
warnings.simplefilter(action='ignore', category=FutureWarning) #QUITAR WARNINGS MOLESTOS
pd.set_option('display.max_columns', None)                     #ELIMINA LIMITES DE PANDAS PARA MOSTRAR COLUMNAS
pd.set_option('display.max_rows', None)                        #ELIMINA LIMITES DE PANDAS PARA MOSTRAR FILAS
pd.set_option('display.max_colwidth', None)                    #AUTOAJUSTA ANCHO DE COLUMNAS

# %%
#CARGANDO DATA
path = "https://raw.githubusercontent.com/hector1994/sp8/refs/heads/master/data_sp8_s1.csv"
df   = pd.read_csv(path)

# %%
df.head()
# Out:
#    age   bmi  bp_sys  glucose  exercise  stress  cortisol     cost  \
# 0   21  29.1   140.1    113.2      20.4     5.7     16.40  5148.81
# 1   66  21.3   122.0    111.1      24.9     9.9     27.01  1405.51
# 2   68  27.4   133.3    113.9      18.3     3.7     11.19  2275.68
# 3   64  28.8   138.4    122.7      16.2     1.2      3.78  2418.09
# 4   35  37.7   173.0    124.6       4.9     7.6     21.51  5354.57
#
#         state        soda    insur gender smoke  score
# 0     Yucatán      Weekly  Private      M    No     54
# 1  Nuevo León       Never   Public     NB   Yes     84
# 2      Oaxaca  Occasional   Public      F    No     22
# 3      Puebla  Occasional   Public     NB   Yes     59
# 4  Nuevo León       Daily  Private     NB    No     61

# %%
df.shape
# Out:
# (1000000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 14 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   age       1000000 non-null  int64
#  1   bmi       1000000 non-null  float64
#  2   bp_sys    1000000 non-null  float64
#  3   glucose   1000000 non-null  float64
#  4   exercise  1000000 non-null  float64
#  5   stress    1000000 non-null  float64
#  6   cortisol  1000000 non-null  float64
#  7   cost      1000000 non-null  float64
#  8   state     1000000 non-null  object
#  9   soda      1000000 non-null  object
#  10  insur     1000000 non-null  object
#  11  gender    1000000 non-null  object
#  12  smoke     1000000 non-null  object
#  13  score     1000000 non-null  int64
# dtypes: float64(7), int64(2), object(5)
# memory usage: 106.8+ MB

# %%
df.describe()
# Out:
#                   age             bmi          bp_sys         glucose  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean        51.013470       27.392755      139.557650      110.604338
# std         19.334254        5.353594       17.845351        9.880306
# min         18.000000       11.200000       98.400000       69.500000
# 25%         34.000000       23.400000      125.800000      103.800000
# 50%         51.000000       26.800000      136.900000      110.200000
# 75%         68.000000       30.800000      150.100000      117.100000
# max         84.000000       57.200000      199.000000      157.800000
#
#              exercise          stress        cortisol            cost  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean        17.584724        5.502206       15.404246     3599.011361
# std          6.538832        2.601068        7.377685     2024.385187
# min          0.000000        1.000000       -1.490000      734.750000
# 25%         13.300000        3.200000        9.100000     2081.670000
# 50%         18.000000        5.500000       15.400000     2494.515000
# 75%         22.300000        7.800000       21.720000     4851.292500
# max         30.000000       10.000000       32.720000     9882.840000
#
#                 score
# count  1000000.000000
# mean        50.488846
# std         28.855616
# min          1.000000
# 25%         26.000000
# 50%         50.000000
# 75%         75.000000
# max        100.000000

# %%
#CÁLCULO DE COEFICIENTE DE CORRELACIÓN DE PEARSON.

# %%
corr_age_bmi_pearson = df['age'].corr(df['bmi'], method = 'pearson')

# %%
corr_age_bmi_pearson
# Out:
# np.float64(0.00053252957889969)

# %%
#MATRIZ DE CORRELACIÓN: ALMACENA TODOS LOS COEF. DE CORRELACIÓN POR PARES.

# %%
matriz_correlacion_pearson  = df.corr(numeric_only = True, method = 'pearson')
matriz_correlacion_separman = df.corr(numeric_only = True, method = 'spearman')

# %%
matriz_correlacion_pearson
# Out:
#                age       bmi    bp_sys   glucose  exercise    stress  \
# age       1.000000  0.000533  0.109102  0.000884 -0.000803  0.001238
# bmi       0.000533  1.000000  0.876756  0.704537 -0.801810 -0.000653
# bp_sys    0.109102  0.876756  1.000000  0.617651 -0.704645 -0.000978
# glucose   0.000884  0.704537  0.617651  1.000000 -0.565359 -0.002643
# exercise -0.000803 -0.801810 -0.704645 -0.565359  1.000000 -0.000096
# stress    0.001238 -0.000653 -0.000978 -0.002643 -0.000096  1.000000
# cortisol  0.001335 -0.000622 -0.000965 -0.002723 -0.000268  0.986648
# cost     -0.000364  0.131418  0.114752  0.091960 -0.105063 -0.000971
# score    -0.000069  0.000158  0.000304  0.000346 -0.000334  0.001309
#
#           cortisol      cost     score
# age       0.001335 -0.000364 -0.000069
# bmi      -0.000622  0.131418  0.000158
# bp_sys   -0.000965  0.114752  0.000304
# glucose  -0.002723  0.091960  0.000346
# exercise -0.000268 -0.105063 -0.000334
# stress    0.986648 -0.000971  0.001309
# cortisol  1.000000 -0.000797  0.001369
# cost     -0.000797  1.000000 -0.001049
# score     0.001369 -0.001049  1.000000

# %%
#HEATMAP: MAPA DE CALOR ASOCIADO A LA MATRIZ DE CORRELACIONES - PEARSON

plt.figure(figsize = (10, 10), dpi = 150)
sns.heatmap(data = matriz_correlacion_pearson,
            annot = True,
            cmap = 'RdBu_r')

plt.title("HEATMAP - COEFICIENTE DE CORRELACIÓN DE PEARSON", fontsize = 22)
plt.savefig("Mapa_calor_df.png", dpi= 150)
plt.show()

# %%
df.shape
# Out:
# (1000000, 14)

# %%
#TOMAR UNA MUESTRA ALEATORIA DE TAMAÑO ESPECÍFICO.
sample_size = 100000
df_sample   =  df.sample(sample_size)

# %%
df_sample.reset_index().head()
# Out:
#     index  age   bmi  bp_sys  glucose  exercise  stress  cortisol     cost  \
# 0  114834   20  23.5   114.1    105.8      21.0     3.1      8.78  4452.39
# 1  953634   49  39.8   176.0    132.3       5.1     8.0     20.47  2898.63
# 2  570108   47  28.8   146.7    113.3      20.9     4.5     13.66  8269.02
# 3  938222   44  29.2   133.4    107.8      20.9     6.2     16.06  2271.56
# 4  613189   51  24.1   128.2    104.0      18.7     2.2      6.47  1984.93
#
#       state        soda    insur gender smoke  score
# 0      CDMX       Never  Private     NB   Yes     92
# 1   Jalisco       Daily   Public      F   Yes     17
# 2    Oaxaca      Weekly  Premium     NB    No     57
# 3  Veracruz  Occasional   Public      F    No     98
# 4    Oaxaca  Occasional   Public      M    No     69

# %%
df_sample.shape
# Out:
# (100000, 14)

# %%
plt.figure(figsize = (15, 5), dpi = 150)

sns.scatterplot(
    data = df_sample,
    x='exercise',
    y='bmi',
    palette='bright',
    alpha = 0.7
)

plt.title('Correlación Negativa: Horas de Ejercicio vs IMC', fontsize=14)
plt.xlabel('Horas de Ejercicio Semanal', fontsize=12)
plt.ylabel('Índice de Masa Corporal (BMI)', fontsize=12)
#plt.grid(True, linestyle='--', alpha=0.5)

plt.savefig("Horas_ejercico_IMC_fumadores.png", dpi = 150)
plt.show()
# Out:
# /tmp/ipykernel_8732/362682014.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(

# %% [markdown]
# ### __Correlación Punto Biserial__
# ---

# %%
df.head()
# Out:
#    age   bmi  bp_sys  glucose  exercise  stress  cortisol     cost  \
# 0   21  29.1   140.1    113.2      20.4     5.7     16.40  5148.81
# 1   66  21.3   122.0    111.1      24.9     9.9     27.01  1405.51
# 2   68  27.4   133.3    113.9      18.3     3.7     11.19  2275.68
# 3   64  28.8   138.4    122.7      16.2     1.2      3.78  2418.09
# 4   35  37.7   173.0    124.6       4.9     7.6     21.51  5354.57
#
#         state        soda    insur gender smoke  score
# 0     Yucatán      Weekly  Private      M    No     54
# 1  Nuevo León       Never   Public     NB   Yes     84
# 2      Oaxaca  Occasional   Public      F    No     22
# 3      Puebla  Occasional   Public     NB   Yes     59
# 4  Nuevo León       Daily  Private     NB    No     61

# %%
df['smoker_encoded'] = df['smoke'].replace({'Yes': 1, 'No':0})

# %%
df.head()
# Out:
#    age   bmi  bp_sys  glucose  exercise  stress  cortisol     cost  \
# 0   21  29.1   140.1    113.2      20.4     5.7     16.40  5148.81
# 1   66  21.3   122.0    111.1      24.9     9.9     27.01  1405.51
# 2   68  27.4   133.3    113.9      18.3     3.7     11.19  2275.68
# 3   64  28.8   138.4    122.7      16.2     1.2      3.78  2418.09
# 4   35  37.7   173.0    124.6       4.9     7.6     21.51  5354.57
#
#         state        soda    insur gender smoke  score  smoker_encoded
# 0     Yucatán      Weekly  Private      M    No     54               0
# 1  Nuevo León       Never   Public     NB   Yes     84               1
# 2      Oaxaca  Occasional   Public      F    No     22               0
# 3      Puebla  Occasional   Public     NB   Yes     59               1
# 4  Nuevo León       Daily  Private     NB    No     61               0

# %%
from scipy.stats import pointbiserialr

# %%
pointbiserialr(df['smoker_encoded'], df['bmi'])
# Out:
# SignificanceResult(statistic=np.float64(0.001434353102368297), pvalue=np.float64(0.15147182457077205))

# %%
path = "https://raw.githubusercontent.com/hector1994/sp8/refs/heads/master/sp8_2.csv"
df   =  pd.read_csv(path)

# %%
df.head()
# Out:
#    Unnamed: 0  customer_age customer_gender  is_premium_member  \
# 0           0            56               F                  0
# 1           1            69               F                  1
# 2           2            46               M                  0
# 3           3            32               M                  0
# 4           4            60               M                  1
#
#   product_category  unit_price  quantity  total_spent  tax_amount  \
# 0           Beauty   66.298089         3   198.894267   37.789911
# 1            Books   14.903286         4    59.613145   11.326498
# 2             Home  210.687352         5  1053.436762  200.152985
# 3             Home  131.207198         3   393.621594   74.788103
# 4             Home  148.207698         3   444.623095   84.478388
#
#    customer_rating  review_count payment_method  used_discount_coupon  \
# 0                4            59         Crypto                     1
# 1                1            21         Crypto                     0
# 2                5            43         PayPal                     0
# 3                5            56     Debit Card                     0
# 4                2            15         PayPal                     1
#
#    returned_item shipping_region device_type
# 0              0            East      Mobile
# 1              0           North      Mobile
# 2              0            West     Desktop
# 3              0            East      Mobile
# 4              0            East     Desktop

# %%
pointbiserialr(df['unit_price'], df['returned_item'])
# Out:
# SignificanceResult(statistic=np.float64(0.4311069433926622), pvalue=np.float64(0.0))

# %%
plt.figure(figsize = (15,5))

sns.barplot(
    data = df,
    x = "returned_item",
    y = "unit_price",
    estimator = "mean",
    palette = 'bright',
    edgecolor = 'black',
    errorbar = None
)

plt.title("Unit prices v/s returned_item", fontsize = 20)
plt.show()

# %% [markdown]
# ### __Correlación entre dos variables categóricas__. V de Cramér
# ---

# %%
column_list_1 = ['product_category', 'payment_method']
column_list_2 = ['device_type','shipping_region']

# %%
df[column_list_1].head()
# Out:
#   product_category payment_method
# 0           Beauty         Crypto
# 1            Books         Crypto
# 2             Home         PayPal
# 3             Home     Debit Card
# 4             Home         PayPal

# %%
df[column_list_2].head()
# Out:
#   device_type shipping_region
# 0      Mobile            East
# 1      Mobile           North
# 2     Desktop            West
# 3      Mobile            East
# 4     Desktop            East

# %%
tabla_1 = pd.crosstab(df['product_category'], df['payment_method'])
tabla_1
# Out:
# payment_method    Credit Card  Crypto  Debit Card  PayPal
# product_category
# Beauty                   2519    2469        2444    2490
# Books                    3763    3850        3772    3704
# Clothing                 6183    6179        6253    6188
# Electronics              7646    7523        7466    7483
# Home                     5084    4947        5031    5006

# %%
from scipy.stats import chi2_contingency

# %%
chi2,_,_,_ = chi2_contingency(tabla_1)   #ESTADÍSTICO DE X^2
n = tabla_1.sum().sum() #FORMA FANCY CALCULAR LA CANTIDAD DE REGISTROS.
chi2
# Out:
# np.float64(6.96568287148234)

# %%
cramers_v = np.sqrt(chi2/(n*(min(tabla_1.shape)-1)))
cramers_v
# Out:
# np.float64(0.004818603833574735)
